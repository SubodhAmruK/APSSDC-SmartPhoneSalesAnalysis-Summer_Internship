# %% [markdown]
# <a href="https://colab.research.google.com/github/SubodhAmruK/APSSDC-SmartPhoneSalesAnalysis-Summer_Internship/blob/main/APSSDC_Internship_SmartPhoneSalesAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Classes/3rd Year/Data-Analysis_Summer-Internship/MobilePhoneSales.csv')
df
# Out:
#                              Mobile Name RAM GB  ROM GB   Ratings  Reviews  \
# 0            Redmi 8 (Onyx Black, 64 GB)   4 GB   64 GB  674638.0  50064.0
# 1        Realme 5i (Forest Green, 64 GB)   4 GB   64 GB  243106.0  16497.0
# 2           Realme 5i (Aqua Blue, 64 GB)   4 GB   64 GB  243106.0  16497.0
# 3         Redmi 8 (Sapphire Blue, 64 GB)   4 GB   32 GB  674638.0  50064.0
# 4        POCO X2 (Matrix Purple, 128 GB)   6 GB   64 GB  133486.0  14732.0
# ...                                  ...    ...     ...       ...      ...
# 1099     ViVO Z1Pro (Sonic Black, 64 GB)   4 GB   64 GB  354415.0  35385.0
# 1100  Alcatel 5V (Spectrum Black, 32 GB)   3 GB   32 GB     169.0     37.0
# 1101     realme X2 (Pearl Green, 128 GB)   6 GB  128 GB   22282.0   2558.0
# 1102     realme X2 (Pearl White, 128 GB)   6 GB  128 GB   22282.0   2558.0
# 1103                          Grabo HULK  64 MB   64 MB     373.0     30.0
#
#       Stars  List Price  Sales Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Mobile Name  1104 non-null   object
#  1   RAM GB       1035 non-null   object
#  2   ROM GB       1088 non-null   object
#  3   Ratings      1095 non-null   float64
#  4   Reviews      1095 non-null   float64
#  5   Stars        1104 non-null   float64
#  6   List Price   817 non-null    float64
#  7   Sales Price  1104 non-null   int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 69.1+ KB

# %%
# create a new column name Brand which is filled from Mobile Name colum
df.insert(0,'Brand',df['Mobile Name'].str.split(n=1).str[0])
df
# Out:
#         Brand                         Mobile Name RAM GB  ROM GB   Ratings  \
# 0       Redmi         Redmi 8 (Onyx Black, 64 GB)   4 GB   64 GB  674638.0
# 1      Realme     Realme 5i (Forest Green, 64 GB)   4 GB   64 GB  243106.0
# 2      Realme        Realme 5i (Aqua Blue, 64 GB)   4 GB   64 GB  243106.0
# 3       Redmi      Redmi 8 (Sapphire Blue, 64 GB)   4 GB   32 GB  674638.0
# 4        POCO     POCO X2 (Matrix Purple, 128 GB)   6 GB   64 GB  133486.0
# ...       ...                                 ...    ...     ...       ...
# 1099     ViVO     ViVO Z1Pro (Sonic Black, 64 GB)   4 GB   64 GB  354415.0
# 1100  Alcatel  Alcatel 5V (Spectrum Black, 32 GB)   3 GB   32 GB     169.0
# 1101   realme     realme X2 (Pearl Green, 128 GB)   6 GB  128 GB   22282.0
# 1102   realme     realme X2 (Pearl White, 128 GB)   6 GB  128 GB   22282.0
# 1103    Grabo                          Grabo HULK  64 MB   64 MB     373.0
#
#       Reviews  Stars  List Price  Sales Price
# ...

# %%
# Convert all data in the 'Brand' column to capital letters
df['Brand'] = df['Brand'].str.upper()
df
# Out:
#         Brand                         Mobile Name RAM GB  ROM GB   Ratings  \
# 0       REDMI         Redmi 8 (Onyx Black, 64 GB)   4 GB   64 GB  674638.0
# 1      REALME     Realme 5i (Forest Green, 64 GB)   4 GB   64 GB  243106.0
# 2      REALME        Realme 5i (Aqua Blue, 64 GB)   4 GB   64 GB  243106.0
# 3       REDMI      Redmi 8 (Sapphire Blue, 64 GB)   4 GB   32 GB  674638.0
# 4        POCO     POCO X2 (Matrix Purple, 128 GB)   6 GB   64 GB  133486.0
# ...       ...                                 ...    ...     ...       ...
# 1099     VIVO     ViVO Z1Pro (Sonic Black, 64 GB)   4 GB   64 GB  354415.0
# 1100  ALCATEL  Alcatel 5V (Spectrum Black, 32 GB)   3 GB   32 GB     169.0
# 1101   REALME     realme X2 (Pearl Green, 128 GB)   6 GB  128 GB   22282.0
# 1102   REALME     realme X2 (Pearl White, 128 GB)   6 GB  128 GB   22282.0
# 1103    GRABO                          Grabo HULK  64 MB   64 MB     373.0
#
#       Reviews  Stars  List Price  Sales Price
# ...

# %%
df[df['Brand']=='KECHAODA'].head(50)
# Out:
#         Brand         Mobile Name  RAM GB ROM GB  Ratings  Reviews  Stars  \
# 328  KECHAODA       Kechaoda K115   32 MB  32 MB   1327.0    111.0    4.4
# 343  KECHAODA       Kechaoda K115   32 MB  32 MB  18672.0   1616.0    4.1
# 361  KECHAODA       Kechaoda K115   32 MB  32 MB  18672.0   1616.0    4.1
# 385  KECHAODA       Kechaoda K112   32 MB  64 MB   9262.0   1113.0    4.0
# 386  KECHAODA       Kechaoda K112   32 MB  64 MB   9262.0   1113.0    4.0
# 447  KECHAODA        Kechaoda K33   32 MB  32 MB   4311.0    339.0    4.1
# 486  KECHAODA       Kechaoda K115   32 MB  32 MB  18672.0   1616.0    4.1
# 487  KECHAODA       Kechaoda K115   32 MB  32 MB  18672.0   1616.0    4.1
# 488  KECHAODA       Kechaoda K115   32 MB  32 MB  18672.0   1616.0    4.1
# 509  KECHAODA        Kechaoda A26   32 MB  32 MB   6307.0    531.0    4.1
# 510  KECHAODA        Kechaoda A26   32 MB  32 MB   6307.0    531.0    4.1
# 513  KECHAODA        Kechaoda K10   32 MB  32 MB   8527.0    616.0    4.0
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#         Brand                            Mobile Name RAM GB  ROM GB   Ratings  \
# 16      APPLE         Apple iPhone XR (Black, 64 GB)    NaN   32 GB   11572.0
# 25      APPLE         Apple iPhone SE (White, 64 GB)    NaN   64 GB   12954.0
# 29      APPLE         Apple iPhone SE (Black, 64 GB)    NaN   32 GB   12954.0
# 30      APPLE  Apple iPhone XR ((PRODUCT)RED, 64 GB)    NaN   64 GB   11572.0
# 32      APPLE           Apple iPhone SE (Red, 64 GB)    NaN  128 GB   12954.0
# ...       ...                                    ...    ...     ...       ...
# 1099     VIVO        ViVO Z1Pro (Sonic Black, 64 GB)   4 GB   64 GB  354415.0
# 1100  ALCATEL     Alcatel 5V (Spectrum Black, 32 GB)   3 GB   32 GB     169.0
# 1101   REALME        realme X2 (Pearl Green, 128 GB)   6 GB  128 GB   22282.0
# 1102   REALME        realme X2 (Pearl White, 128 GB)   6 GB  128 GB   22282.0
# 1103    GRABO                             Grabo HULK  64 MB   64 MB     373.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Brand            0
# Mobile Name      0
# RAM GB          69
# ROM GB          16
# Ratings          9
# Reviews          9
# Stars            0
# List Price     287
# Sales Price      0
# dtype: int64

# %%
df[df['List Price'].isnull() & df['RAM GB'].isnull() & df['ROM GB'].isnull()]
# Out:
#         Brand           Mobile Name RAM GB ROM GB   Ratings  Reviews  Stars  \
# 262   SAMSUNG  SAMSUNG Guru Music 2    NaN    NaN  166530.0  16289.0    4.3
# 668   KARBONN            KARBONN K9    NaN    NaN    5681.0    519.0    4.1
# 1094  SAMSUNG  SAMSUNG Guru FM Plus    NaN    NaN   21692.0   2009.0    4.2
#
#       List Price  Sales Price
# 262          NaN         1710
# 668          NaN         1248
# 1094         NaN         1567

# %%
df['List Price'].fillna(df['Sales Price'].median(),inplace=True)
df
# Out:
#         Brand                         Mobile Name RAM GB  ROM GB   Ratings  \
# 0       REDMI         Redmi 8 (Onyx Black, 64 GB)   4 GB   64 GB  674638.0
# 1      REALME     Realme 5i (Forest Green, 64 GB)   4 GB   64 GB  243106.0
# 2      REALME        Realme 5i (Aqua Blue, 64 GB)   4 GB   64 GB  243106.0
# 3       REDMI      Redmi 8 (Sapphire Blue, 64 GB)   4 GB   32 GB  674638.0
# 4        POCO     POCO X2 (Matrix Purple, 128 GB)   6 GB   64 GB  133486.0
# ...       ...                                 ...    ...     ...       ...
# 1099     VIVO     ViVO Z1Pro (Sonic Black, 64 GB)   4 GB   64 GB  354415.0
# 1100  ALCATEL  Alcatel 5V (Spectrum Black, 32 GB)   3 GB   32 GB     169.0
# 1101   REALME     realme X2 (Pearl Green, 128 GB)   6 GB  128 GB   22282.0
# 1102   REALME     realme X2 (Pearl White, 128 GB)   6 GB  128 GB   22282.0
# 1103    GRABO                          Grabo HULK  64 MB   64 MB     373.0
#
#       Reviews  Stars  List Price  Sales Price
# ...

# %%
df.isnull().sum()
# Out:
# Brand           0
# Mobile Name     0
# RAM GB         69
# ROM GB         16
# Ratings         9
# Reviews         9
# Stars           0
# List Price      0
# Sales Price     0
# dtype: int64

# %%
df[df['Mobile Name'].str.contains('Apple')]
# Out:
#       Brand                                        Mobile Name RAM GB  ROM GB  \
# 16    APPLE                     Apple iPhone XR (Black, 64 GB)    NaN   32 GB
# 25    APPLE                     Apple iPhone SE (White, 64 GB)    NaN   64 GB
# 29    APPLE                     Apple iPhone SE (Black, 64 GB)    NaN   32 GB
# 30    APPLE              Apple iPhone XR ((PRODUCT)RED, 64 GB)    NaN   64 GB
# 32    APPLE                       Apple iPhone SE (Red, 64 GB)    NaN  128 GB
# 43    APPLE                    Apple iPhone SE (Black, 128 GB)    NaN   64 GB
# 47    APPLE                      Apple iPhone XR (Blue, 64 GB)    NaN  128 GB
# 48    APPLE                      Apple iPhone XR (Blue, 64 GB)    NaN   64 GB
# 77    APPLE                 Apple iPhone 7 Plus (Black, 32 GB)    NaN   64 GB
# 95    APPLE                    Apple iPhone XR (White, 128 GB)    NaN   64 GB
# 119   APPLE                     Apple iPhone XR (White, 64 GB)    NaN   64 GB
# ...

# %%
# Fill the 'RAM GB' column with "4 GB" where the 'Brand' column is "Apple"
df.loc[df['Brand'] == 'APPLE', 'RAM GB'] = '4 GB'
df
# Out:
#         Brand                         Mobile Name RAM GB  ROM GB   Ratings  \
# 0       REDMI         Redmi 8 (Onyx Black, 64 GB)   4 GB   64 GB  674638.0
# 1      REALME     Realme 5i (Forest Green, 64 GB)   4 GB   64 GB  243106.0
# 2      REALME        Realme 5i (Aqua Blue, 64 GB)   4 GB   64 GB  243106.0
# 3       REDMI      Redmi 8 (Sapphire Blue, 64 GB)   4 GB   32 GB  674638.0
# 4        POCO     POCO X2 (Matrix Purple, 128 GB)   6 GB   64 GB  133486.0
# ...       ...                                 ...    ...     ...       ...
# 1099     VIVO     ViVO Z1Pro (Sonic Black, 64 GB)   4 GB   64 GB  354415.0
# 1100  ALCATEL  Alcatel 5V (Spectrum Black, 32 GB)   3 GB   32 GB     169.0
# 1101   REALME     realme X2 (Pearl Green, 128 GB)   6 GB  128 GB   22282.0
# 1102   REALME     realme X2 (Pearl White, 128 GB)   6 GB  128 GB   22282.0
# 1103    GRABO                          Grabo HULK  64 MB   64 MB     373.0
#
#       Reviews  Stars  List Price  Sales Price
# ...

# %%
df[df['Mobile Name'].str.contains('Apple')]
# Out:
#       Brand                                        Mobile Name RAM GB  ROM GB  \
# 16    APPLE                     Apple iPhone XR (Black, 64 GB)   4 GB   32 GB
# 25    APPLE                     Apple iPhone SE (White, 64 GB)   4 GB   64 GB
# 29    APPLE                     Apple iPhone SE (Black, 64 GB)   4 GB   32 GB
# 30    APPLE              Apple iPhone XR ((PRODUCT)RED, 64 GB)   4 GB   64 GB
# 32    APPLE                       Apple iPhone SE (Red, 64 GB)   4 GB  128 GB
# 43    APPLE                    Apple iPhone SE (Black, 128 GB)   4 GB   64 GB
# 47    APPLE                      Apple iPhone XR (Blue, 64 GB)   4 GB  128 GB
# 48    APPLE                      Apple iPhone XR (Blue, 64 GB)   4 GB   64 GB
# 77    APPLE                 Apple iPhone 7 Plus (Black, 32 GB)   4 GB   64 GB
# 95    APPLE                    Apple iPhone XR (White, 128 GB)   4 GB   64 GB
# 119   APPLE                     Apple iPhone XR (White, 64 GB)   4 GB   64 GB
# ...

# %%
df[df['RAM GB'].isnull() & df['ROM GB'].isnull()]
# Out:
#         Brand                      Mobile Name RAM GB ROM GB   Ratings  \
# 254   SAMSUNG                SAMSUNG Guru 1200    NaN    NaN  151745.0
# 262   SAMSUNG             SAMSUNG Guru Music 2    NaN    NaN  166530.0
# 281   SAMSUNG                SAMSUNG Guru 1200    NaN    NaN  151745.0
# 297   SAMSUNG             SAMSUNG Guru Music 2    NaN    NaN  166530.0
# 301   SAMSUNG  SAMSUNG Guru FM Plus SM-B110E/D    NaN    NaN   54274.0
# 306   SAMSUNG             SAMSUNG Guru Music 2    NaN    NaN  166530.0
# 322   SAMSUNG  SAMSUNG Guru FM Plus SM-B110E/D    NaN    NaN    1384.0
# 413   KARBONN                       KARBONN K9    NaN    NaN    5681.0
# 423   SAMSUNG                SAMSUNG Guru 1200    NaN    NaN  151745.0
# 449   SAMSUNG             SAMSUNG Guru FM Plus    NaN    NaN   21692.0
# 482   SAMSUNG  SAMSUNG Guru FM Plus SM-B110E/D    NaN    NaN   54274.0
# 583   SAMSUNG             SAMSUNG Guru FM Plus    NaN    NaN   21684.0
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Brand          0
# Mobile Name    0
# RAM GB         0
# ROM GB         0
# Ratings        0
# Reviews        0
# Stars          0
# List Price     0
# Sales Price    0
# dtype: int64

# %%
df[df["Brand"]=='APPLE']
# Out:
#       Brand                                        Mobile Name RAM GB  ROM GB  \
# 16    APPLE                     Apple iPhone XR (Black, 64 GB)   4 GB   32 GB
# 25    APPLE                     Apple iPhone SE (White, 64 GB)   4 GB   64 GB
# 29    APPLE                     Apple iPhone SE (Black, 64 GB)   4 GB   32 GB
# 30    APPLE              Apple iPhone XR ((PRODUCT)RED, 64 GB)   4 GB   64 GB
# 32    APPLE                       Apple iPhone SE (Red, 64 GB)   4 GB  128 GB
# 43    APPLE                    Apple iPhone SE (Black, 128 GB)   4 GB   64 GB
# 47    APPLE                      Apple iPhone XR (Blue, 64 GB)   4 GB  128 GB
# 48    APPLE                      Apple iPhone XR (Blue, 64 GB)   4 GB   64 GB
# 77    APPLE                 Apple iPhone 7 Plus (Black, 32 GB)   4 GB   64 GB
# 95    APPLE                    Apple iPhone XR (White, 128 GB)   4 GB   64 GB
# 119   APPLE                     Apple iPhone XR (White, 64 GB)   4 GB   64 GB
# ...

# %%
df['Brand'].unique()
# Out:
# array(['REDMI', 'REALME', 'POCO', 'APPLE', 'INFINIX', 'MOTOROLA', 'OPPO',
#        'VIVO', 'I', 'NOKIA', 'TECNO', 'LAVA', 'GIONEE', 'SAMSUNG', 'IQOO',
#        'GOOGLE', 'GRABO', 'MICROMAX', 'ITEL', 'GFIVE', 'MI', 'KECHAODA',
#        'KARBONN', 'SALORA', 'GOOD', 'GREENBERRI', 'SNEXIAN', 'BLACKZONE',
#        'PANASONIC', 'MOTO', 'ADCOM', 'MU', 'UISMART', 'GEOTEL', 'ANGAGE',
#        'FORME', 'ISMART', 'TORK', 'DETEL', 'BLACKBEAR', 'COOLPAD', 'JIVI',
#        'PHILIPS', 'HONOR', 'KXD', 'JIO', 'SSKY', 'GREENBERRY', 'MTR',
#        'MUPHONE', 'MARQ', 'HUAWEI', 'LG', 'ROKEA', 'EASYFONE', 'ALCATEL'],
#       dtype=object)

# %%
df[df['Brand']=='BLACKBEAR']
# Out:
#          Brand             Mobile Name RAM GB ROM GB  Ratings  Reviews  Stars  \
# 763  BLACKBEAR       BlackBear i7 Trio  24 MB  24 MB    122.0     10.0    3.9
# 917  BLACKBEAR  BlackBear A1 Pen Phone  64 MB  32 MB    168.0      8.0    3.8
#
#      List Price  Sales Price
# 763      8405.0         1699
# 917       779.0         1899

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1068 entries, 0 to 1103
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        1068 non-null   object
#  1   Mobile Name  1068 non-null   object
#  2   RAM GB       1068 non-null   object
#  3   ROM GB       1068 non-null   object
#  4   Ratings      1068 non-null   float64
#  5   Reviews      1068 non-null   float64
#  6   Stars        1068 non-null   float64
#  7   List Price   1068 non-null   float64
#  8   Sales Price  1068 non-null   int64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 83.4+ KB

# %%
df[df['RAM GB'].str.contains('QVGA Display0.1MP Rear Camera1800 mAh Battery6 Month')]
# Out:
# Empty DataFrame
# Columns: [Brand, Mobile Name, RAM GB, ROM GB, Ratings, Reviews, Stars, List Price, Sales Price]
# Index: []

# %%
# Define a function to convert RAM values to GB
def convert_to_gb(value):
    if pd.notna(value):
        if 'GB' in value:
            return float(value.replace(' GB', ''))
        elif 'MB' in value:
            return float(value.replace(' MB', '')) / 1024.0  # Convert MB to GB
        elif 'KB' in value:
            return float(value.replace(' KB', '')) / 1024.0 / 1024.0  # Convert KB to GB
    return pd.NA  # Handle NaN values or other cases

# Apply the conversion function to the 'RAM GB' column
df['RAM GB'] = df['RAM GB'].apply(convert_to_gb)

# %%
# Define a function to convert RAM values to GB
def convert_to_gb(value):
    if pd.notna(value):
        if 'GB' in value:
            return float(value.replace(' GB', ''))
        elif 'MB' in value:
            return float(value.replace('MB', '')) / 1024.0  # Convert MB to GB
        elif 'KB' in value:
            return float(value.replace(' KB', '')) / 1024.0 / 1024.0  # Convert KB to GB
    else:
      return pd.NA  # Handle NaN values or other cases

# Apply the conversion function to the 'RAM GB' column
df['ROM GB'] = df['ROM GB'].apply(convert_to_gb)

# %%
df
# Out:
#         Brand                         Mobile Name  RAM GB    ROM GB   Ratings  \
# 0       REDMI         Redmi 8 (Onyx Black, 64 GB)  4.0000   64.0000  674638.0
# 1      REALME     Realme 5i (Forest Green, 64 GB)  4.0000   64.0000  243106.0
# 2      REALME        Realme 5i (Aqua Blue, 64 GB)  4.0000   64.0000  243106.0
# 3       REDMI      Redmi 8 (Sapphire Blue, 64 GB)  4.0000   32.0000  674638.0
# 4        POCO     POCO X2 (Matrix Purple, 128 GB)  6.0000   64.0000  133486.0
# ...       ...                                 ...     ...       ...       ...
# 1099     VIVO     ViVO Z1Pro (Sonic Black, 64 GB)  4.0000   64.0000  354415.0
# 1100  ALCATEL  Alcatel 5V (Spectrum Black, 32 GB)  3.0000   32.0000     169.0
# 1101   REALME     realme X2 (Pearl Green, 128 GB)  6.0000  128.0000   22282.0
# 1102   REALME     realme X2 (Pearl White, 128 GB)  6.0000  128.0000   22282.0
# 1103    GRABO                          Grabo HULK  0.0625    0.0625     373.0
#
# ...

# %%
# Custom color palette for the plot
colors = sns.color_palette('pastel')

# Calculate the average rating and review count for each brand
brand_stats = df.groupby('Brand').agg({'Ratings': 'mean', 'Reviews': 'sum'}).reset_index()

# Filter out brands with less than 20,000 reviews and group them as "Other"
threshold = 20000
popular_brands = brand_stats[brand_stats['Reviews'] > threshold]
other_brands = brand_stats[brand_stats['Reviews'] <= threshold]
other_brands_summary = {'Brand': 'Other', 'Ratings': other_brands['Ratings'].mean(), 'Reviews': other_brands['Reviews'].sum()}
popular_brands = popular_brands.append(other_brands_summary, ignore_index=True)

# Bar Plot: Average Ratings for Popular Brands (Reviews > 20000)
plt.figure(figsize=(10, 6))
sns.barplot(data=popular_brands, x='Brand', y='Ratings', palette=colors)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Average Ratings', fontsize=12)
plt.title('Average Ratings for Popular Brands (Reviews > 20000)', fontsize=16)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-26-e8e234ae6d1e>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   popular_brands = popular_brands.append(other_brands_summary, ignore_index=True)

# %%
# Set the threshold for minimum ratings
min_ratings_threshold = 5000

# Filter the data to keep only the rows with ratings greater than the threshold
popular_brands_df = df[df['Reviews'] >= min_ratings_threshold]

# Get the unique brands in the filtered data
unique_brands = popular_brands_df['Brand'].unique()

# Generate a custom color palette with unique colors for each brand using 'hls' color space
custom_palette = sns.color_palette("hls", len(unique_brands))

# Scatter Plot: Ratings vs. Sales Price for Popular Brands (Reviews >= 5000)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=popular_brands_df, x='Sales Price', y='Reviews', hue='Brand', s=100, alpha=0.8, palette=custom_palette)
plt.xlabel('Sales Price')
plt.ylabel('Reviews')
plt.title(f'Reviews vs. Sales Price for Popular Brands (Reviews >= {min_ratings_threshold})', fontsize=16)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Set the threshold for minimum reviews
min_reviews_threshold = 1500
# Filter the data to keep only the rows with reviews greater than the threshold
popular_brands_df = df[df['Reviews'] > min_reviews_threshold]

# Box Plot: Stars for Each Brand (with threshold)
plt.figure(figsize=(10, 6))
sns.boxplot(data=popular_brands_df, x='Brand', y='Stars', palette='pastel')
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Stars', fontsize=12)
plt.title(f'Stars for Each Brand (Reviews > {min_reviews_threshold})', fontsize=16)
plt.xticks(rotation=60, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
popular_brands_df = df[df['Reviews'] > 20000]
plt.figure(figsize=(10, 6))
plt.bar(popular_brands_df['Brand'], popular_brands_df['Ratings'], color='skyblue')
plt.xlabel('Brand')
plt.ylabel('Average Ratings')
plt.title('Average Ratings for Popular Brands (Reviews > 20000)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
